# %% [markdown]
# <a href="https://colab.research.google.com/github/arizaam/Computer-Vision/blob/main/Praktik_OpenCv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Laporan Praktik: Pengantar Pemrosesan Citra dengan Python dan OpenCV (Halaman 19 - 118)
#
# Bab 4: Image Basics
#
# o	Citra dalam OpenCV direpresentasikan sebagai array NumPy multidimensi (Tinggi, Lebar, Saluran).
#
# o	Saluran warna disimpan dalam urutan BGR (Blue, Green, Red), bukan RGB2.
#
# o	Akses dan manipulasi piksel dilakukan menggunakan notasi array slicing NumPy: image[y, x] untuk piksel, dan image[startY:endY, startX:endX] untuk memotong bagian citra (cropping).
